# %% [markdown]
# <a href="https://colab.research.google.com/github/HafidzShahab/Data-Science-2026/blob/main/pertemuan1_%5BAhmad_Hafidz%5D__%5B240401020180%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Ahmad Hafidz
# NIM   : 240401020180
# kelas : IF 401

# %%
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "Ahmad Hafidz"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Ahmad Hafidz", "Informatika", 2024))
# Out:
# Hello, Data Science!
# Halo, Ahmad Hafidz angkatan 2024!
# 1. Python
# 2. Colab
# 3. Jupyter
# 4. GitHub
# Ahmad Hafidz | Informatika | 2024

# %% [markdown]
# Kesimpulan : pada pertemuan ke 1 ini kita diajarkan untuk cara menggunakan python
